# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv('../data/benin-malanville.csv')

# Summary statistics
summary = data.describe()

# Plotting GHI
sns.histplot(data['GHI'])
plt.show()
